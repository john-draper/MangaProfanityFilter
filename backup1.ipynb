# %%
from pathlib import Path
from PIL import Image
import easyocr
import numpy as np
from sklearn.cluster import DBSCAN
import os
from pathlib import Path
from paddleocr import PaddleOCR
from PIL import Image, ImageDraw, ImageFont
import re
import json
import string

# %%
# --------------------------
# CONFIG
# --------------------------
input_folder = Path(r"input")
output_folder = Path("output")
output_folder.mkdir(exist_ok=True)

allow_chars = "ABCDEFGHIJKLMNOPQRSTUVWXYZ012356789!?.,-…'\""

# Load replacements from JSON file
with open("replacements.json", "r", encoding="utf-8") as f:
    replacements = json.load(f)

font_path = "fonts/CCMeanwhileBoldItalic.ttf"
font_size = 16

# --------------------------
# INITIALIZE OCR
# --------------------------
reader = easyocr.Reader(['en'], gpu=True)

# --------------------------
# HELPER FUNCTIONS
# --------------------------
def natural_sort_key(path):
    return [int(text) if text.isdigit() else text.lower()
            for text in re.split(r'(\d+)', str(path))]

def get_replacement(word, replacements):
    punct = '!?.,-…\'\"'
    core = word.strip(punct)
    key = core.upper()
    if key in replacements:
        core_start = word.find(core)
        pre = word[:core_start]
        post = word[core_start + len(core):]
        return pre + replacements[key] + post
    else:
        return word

def filter_and_replace(results, replacements):
    """Return only the OCR boxes that contain words found in replacements.json."""
    filtered = []
    for bbox, text, conf in results:
        words = text.split()
        replaced_words = []
        found = False
        for word in words:
            replaced_word = get_replacement(word, replacements)
            if replaced_word != word:
                found = True
            replaced_words.append(replaced_word)
        if found:
            new_text = " ".join(replaced_words)
            filtered.append((bbox, new_text, conf))
    return filtered

def draw_text_on_image(img, results, font_path, base_font_size, padding_ratio=0.1):
    """Draws white box + replacement text, scaling font and box to match OCR bbox height."""
    pil_img = img.copy()
    draw = ImageDraw.Draw(pil_img)

    for bbox, text, conf in results:
        # Calculate bounding box height from OCR result
        x_coords = [p[0] for p in bbox]
        y_coords = [p[1] for p in bbox]
        x_center = int(np.mean(x_coords))
        y_center = int(np.mean(y_coords))
        bbox_height = max(y_coords) - min(y_coords)
        bbox_width = max(x_coords) - min(x_coords)

        # Estimate font size proportional to OCR box height
        est_font_size = max(8, int(bbox_height * 0.73))  # Adjust scaling as needed
        font = ImageFont.truetype(font_path, est_font_size)

        # Measure text size using the selected font
        bbox_text = draw.textbbox((0, 0), text, font=font)
        text_width = bbox_text[2] - bbox_text[0]
        text_height = bbox_text[3] - bbox_text[1]

        # Add padding proportional to text size
        padding_x = int(text_width * padding_ratio)
        padding_y = int(text_height * padding_ratio)

        # Define rectangle coordinates
        x0 = x_center - text_width // 2.2 - padding_x
        y0 = y_center - text_height // 2 - padding_y
        x1 = x_center + text_width // 2.2 + padding_x
        y1 = y_center + text_height // 2 + padding_y

        # Draw white rectangle, then replacement text
        draw.rectangle([x0, y0, x1, y1], fill="white")
        draw.text((x_center, y_center), text, fill="black", font=font, anchor="mm")

    return pil_img


# --------------------------
# PROCESS FOLDERS
# --------------------------
folders = [f for f in input_folder.rglob('*') if f.is_dir()] + [input_folder]

for folder in sorted(set(folders)):
    image_files = sorted(
        list(folder.glob("*.webp")) +
        list(folder.glob("*.jpg")) +
        list(folder.glob("*.jpeg")),
        key=natural_sort_key
    )

    if not image_files:
        continue

    print(f"\nProcessing folder: {folder}")

    for img_path in image_files:
        img = Image.open(img_path)
        results = reader.readtext(np.array(img), allowlist=allow_chars, width_ths=0.05)
        # Replace ALL words             (Option 1)
        filtered_results = [(bbox, " ".join([get_replacement(w, replacements) for w in text.split()]), conf) for bbox, text, conf in results]
        # Replace ONLY FILTERED words   (Option 2)
#        filtered_results = filter_and_replace(results, replacements)

        modified_img = draw_text_on_image(img, filtered_results, font_path, font_size)

        relative_path = folder.relative_to(input_folder)
        output_subfolder = output_folder / relative_path
        output_subfolder.mkdir(parents=True, exist_ok=True)

        output_path = output_subfolder / f"{img_path.stem}.png"
        modified_img.save(output_path)
        if filtered_results:
            print(f"  Replacements found → saved: {output_path}")
        else:
            print(f"  No replacements → saved copy: {output_path}")
# Out:
# Processing folder: input\Chainsawman\Chapter_16
#   Replacements found → saved: output\Chainsawman\Chapter_16\page_1.png
#   Replacements found → saved: output\Chainsawman\Chapter_16\page_2.png
#   Replacements found → saved: output\Chainsawman\Chapter_16\page_3.png
#   Replacements found → saved: output\Chainsawman\Chapter_16\page_4.png
#   Replacements found → saved: output\Chainsawman\Chapter_16\page_5.png
#   Replacements found → saved: output\Chainsawman\Chapter_16\page_6.png
#   Replacements found → saved: output\Chainsawman\Chapter_16\page_7.png
#   Replacements found → saved: output\Chainsawman\Chapter_16\page_8.png
#   Replacements found → saved: output\Chainsawman\Chapter_16\page_9.png
#   Replacements found → saved: output\Chainsawman\Chapter_16\page_10.png
#   Replacements found → saved: output\Chainsawman\Chapter_16\page_11.png
#   Replacements found → saved: output\Chainsawman\Chapter_16\page_12.png
#   Replacements found → saved: output\Chainsawman\Chapter_16\page_13.png
#   Replacements found → saved: output\Chainsawman\Chapter_16\page_14.png
#   Replacements found → saved: output\Chainsawman\Chapter_16\page_15.png
#   Replacements found → saved: output\Chainsawman\Chapter_16\page_16.png
#   Replacements found → saved: output\Chainsawman\Chapter_16\page_17.png
#   Replacements found → saved: output\Chainsawman\Chapter_16\page_18.png
#   Replacements found → saved: output\Chainsawman\Chapter_16\page_19.png
#
# Processing folder: input\Chainsawman\Chapter_17
#   Replacements found → saved: output\Chainsawman\Chapter_17\page_1.png
#   Replacements found → saved: output\Chainsawman\Chapter_17\page_2.png
#   Replacements found → saved: output\Chainsawman\Chapter_17\page_3.png
#   Replacements found → saved: output\Chainsawman\Chapter_17\page_4.png
#   Replacements found → saved: output\Chainsawman\Chapter_17\page_5.png
#   Replacements found → saved: output\Chainsawman\Chapter_17\page_6.png
#   Replacements found → saved: output\Chainsawman\Chapter_17\page_7.png
#   Replacements found → saved: output\Chainsawman\Chapter_17\page_8.png
#   Replacements found → saved: output\Chainsawman\Chapter_17\page_9.png
#   Replacements found → saved: output\Chainsawman\Chapter_17\page_10.png
#   Replacements found → saved: output\Chainsawman\Chapter_17\page_11.png
#   Replacements found → saved: output\Chainsawman\Chapter_17\page_12.png
#   Replacements found → saved: output\Chainsawman\Chapter_17\page_13.png
#   Replacements found → saved: output\Chainsawman\Chapter_17\page_14.png
#   Replacements found → saved: output\Chainsawman\Chapter_17\page_15.png
#   Replacements found → saved: output\Chainsawman\Chapter_17\page_16.png
#   Replacements found → saved: output\Chainsawman\Chapter_17\page_17.png
#   Replacements found → saved: output\Chainsawman\Chapter_17\page_18.png
#
# Processing folder: input\Chainsawman\Chapter_18
#   Replacements found → saved: output\Chainsawman\Chapter_18\page_1.png
#   Replacements found → saved: output\Chainsawman\Chapter_18\page_2.png
#   Replacements found → saved: output\Chainsawman\Chapter_18\page_3.png
#   Replacements found → saved: output\Chainsawman\Chapter_18\page_4.png
#   Replacements found → saved: output\Chainsawman\Chapter_18\page_5.png
#   Replacements found → saved: output\Chainsawman\Chapter_18\page_6.png
#   Replacements found → saved: output\Chainsawman\Chapter_18\page_7.png
#   Replacements found → saved: output\Chainsawman\Chapter_18\page_8.png
#   Replacements found → saved: output\Chainsawman\Chapter_18\page_9.png
#   Replacements found → saved: output\Chainsawman\Chapter_18\page_10.png
#   Replacements found → saved: output\Chainsawman\Chapter_18\page_11.png
#   Replacements found → saved: output\Chainsawman\Chapter_18\page_12.png
#   Replacements found → saved: output\Chainsawman\Chapter_18\page_13.png
#   Replacements found → saved: output\Chainsawman\Chapter_18\page_14.png
#   Replacements found → saved: output\Chainsawman\Chapter_18\page_15.png
#   Replacements found → saved: output\Chainsawman\Chapter_18\page_16.png
#   Replacements found → saved: output\Chainsawman\Chapter_18\page_17.png
#   Replacements found → saved: output\Chainsawman\Chapter_18\page_18.png
#   Replacements found → saved: output\Chainsawman\Chapter_18\page_19.png
#
# Processing folder: input\Chainsawman\Chapter_19
#   Replacements found → saved: output\Chainsawman\Chapter_19\page_1.png
#   Replacements found → saved: output\Chainsawman\Chapter_19\page_2.png
#   Replacements found → saved: output\Chainsawman\Chapter_19\page_3.png
#   Replacements found → saved: output\Chainsawman\Chapter_19\page_4.png
#   Replacements found → saved: output\Chainsawman\Chapter_19\page_5.png
#   Replacements found → saved: output\Chainsawman\Chapter_19\page_6.png
#   Replacements found → saved: output\Chainsawman\Chapter_19\page_7.png
#   Replacements found → saved: output\Chainsawman\Chapter_19\page_8.png
#   Replacements found → saved: output\Chainsawman\Chapter_19\page_9.png
#   Replacements found → saved: output\Chainsawman\Chapter_19\page_10.png
#   Replacements found → saved: output\Chainsawman\Chapter_19\page_11.png
#   Replacements found → saved: output\Chainsawman\Chapter_19\page_12.png
#   Replacements found → saved: output\Chainsawman\Chapter_19\page_13.png
#   Replacements found → saved: output\Chainsawman\Chapter_19\page_14.png
#
# Processing folder: input\Chainsawman\Chapter_20
#   Replacements found → saved: output\Chainsawman\Chapter_20\page_1.png
#   Replacements found → saved: output\Chainsawman\Chapter_20\page_2.png
#   Replacements found → saved: output\Chainsawman\Chapter_20\page_3.png
#   Replacements found → saved: output\Chainsawman\Chapter_20\page_4.png
#   Replacements found → saved: output\Chainsawman\Chapter_20\page_5.png
#   Replacements found → saved: output\Chainsawman\Chapter_20\page_6.png
#   Replacements found → saved: output\Chainsawman\Chapter_20\page_7.png
#   Replacements found → saved: output\Chainsawman\Chapter_20\page_8.png
#   Replacements found → saved: output\Chainsawman\Chapter_20\page_9.png
#   Replacements found → saved: output\Chainsawman\Chapter_20\page_10.png
#   Replacements found → saved: output\Chainsawman\Chapter_20\page_11.png
#   Replacements found → saved: output\Chainsawman\Chapter_20\page_12.png
#   Replacements found → saved: output\Chainsawman\Chapter_20\page_13.png
#   Replacements found → saved: output\Chainsawman\Chapter_20\page_14.png
#   Replacements found → saved: output\Chainsawman\Chapter_20\page_15.png
#   Replacements found → saved: output\Chainsawman\Chapter_20\page_16.png
#   Replacements found → saved: output\Chainsawman\Chapter_20\page_17.png
#   Replacements found → saved: output\Chainsawman\Chapter_20\page_18.png
#
# Processing folder: input\Chainsawman\Chapter_21
#   Replacements found → saved: output\Chainsawman\Chapter_21\page_1.png
#   Replacements found → saved: output\Chainsawman\Chapter_21\page_2.png
#   Replacements found → saved: output\Chainsawman\Chapter_21\page_3.png
#   Replacements found → saved: output\Chainsawman\Chapter_21\page_4.png
#   Replacements found → saved: output\Chainsawman\Chapter_21\page_5.png
#   Replacements found → saved: output\Chainsawman\Chapter_21\page_6.png
#   Replacements found → saved: output\Chainsawman\Chapter_21\page_7.png
#   Replacements found → saved: output\Chainsawman\Chapter_21\page_8.png
#   Replacements found → saved: output\Chainsawman\Chapter_21\page_9.png
#   Replacements found → saved: output\Chainsawman\Chapter_21\page_10.png
#   Replacements found → saved: output\Chainsawman\Chapter_21\page_11.png
#   Replacements found → saved: output\Chainsawman\Chapter_21\page_12.png
#   Replacements found → saved: output\Chainsawman\Chapter_21\page_13.png
#   Replacements found → saved: output\Chainsawman\Chapter_21\page_14.png
#   Replacements found → saved: output\Chainsawman\Chapter_21\page_15.png
#   Replacements found → saved: output\Chainsawman\Chapter_21\page_16.png
#   Replacements found → saved: output\Chainsawman\Chapter_21\page_17.png
#   Replacements found → saved: output\Chainsawman\Chapter_21\page_18.png
#   Replacements found → saved: output\Chainsawman\Chapter_21\page_19.png
#
# Processing folder: input\Chainsawman\Chapter_22
#   Replacements found → saved: output\Chainsawman\Chapter_22\page_1.png
#   Replacements found → saved: output\Chainsawman\Chapter_22\page_2.png
#   Replacements found → saved: output\Chainsawman\Chapter_22\page_3.png
#   Replacements found → saved: output\Chainsawman\Chapter_22\page_4.png
#   Replacements found → saved: output\Chainsawman\Chapter_22\page_5.png
#   Replacements found → saved: output\Chainsawman\Chapter_22\page_6.png
#   Replacements found → saved: output\Chainsawman\Chapter_22\page_7.png
#   Replacements found → saved: output\Chainsawman\Chapter_22\page_8.png
#   Replacements found → saved: output\Chainsawman\Chapter_22\page_9.png
#   Replacements found → saved: output\Chainsawman\Chapter_22\page_10.png
#   Replacements found → saved: output\Chainsawman\Chapter_22\page_11.png
#   Replacements found → saved: output\Chainsawman\Chapter_22\page_12.png
#   Replacements found → saved: output\Chainsawman\Chapter_22\page_13.png
#   Replacements found → saved: output\Chainsawman\Chapter_22\page_14.png
#   Replacements found → saved: output\Chainsawman\Chapter_22\page_15.png
#   Replacements found → saved: output\Chainsawman\Chapter_22\page_16.png
#   Replacements found → saved: output\Chainsawman\Chapter_22\page_17.png
#   Replacements found → saved: output\Chainsawman\Chapter_22\page_18.png
#   Replacements found → saved: output\Chainsawman\Chapter_22\page_19.png
#
# Processing folder: input\Chainsawman\Chapter_23
#   Replacements found → saved: output\Chainsawman\Chapter_23\page_1.png
#   Replacements found → saved: output\Chainsawman\Chapter_23\page_2.png
#   Replacements found → saved: output\Chainsawman\Chapter_23\page_3.png
#   Replacements found → saved: output\Chainsawman\Chapter_23\page_4.png
#   Replacements found → saved: output\Chainsawman\Chapter_23\page_5.png
#   Replacements found → saved: output\Chainsawman\Chapter_23\page_6.png
#   Replacements found → saved: output\Chainsawman\Chapter_23\page_7.png
#   Replacements found → saved: output\Chainsawman\Chapter_23\page_8.png
#   Replacements found → saved: output\Chainsawman\Chapter_23\page_9.png
#   Replacements found → saved: output\Chainsawman\Chapter_23\page_10.png
#   Replacements found → saved: output\Chainsawman\Chapter_23\page_11.png
#   Replacements found → saved: output\Chainsawman\Chapter_23\page_12.png
#   Replacements found → saved: output\Chainsawman\Chapter_23\page_13.png
#   Replacements found → saved: output\Chainsawman\Chapter_23\page_14.png
#   Replacements found → saved: output\Chainsawman\Chapter_23\page_15.png
#   No replacements → saved copy: output\Chainsawman\Chapter_23\page_16.png
#   No replacements → saved copy: output\Chainsawman\Chapter_23\page_17.png
#   Replacements found → saved: output\Chainsawman\Chapter_23\page_18.png
#   No replacements → saved copy: output\Chainsawman\Chapter_23\page_19.png
#   Replacements found → saved: output\Chainsawman\Chapter_23\page_20.png
#
# Processing folder: input\Chainsawman\Chapter_24
#   Replacements found → saved: output\Chainsawman\Chapter_24\page_1.png
#   Replacements found → saved: output\Chainsawman\Chapter_24\page_2.png
#   Replacements found → saved: output\Chainsawman\Chapter_24\page_3.png
#   Replacements found → saved: output\Chainsawman\Chapter_24\page_4.png
#   Replacements found → saved: output\Chainsawman\Chapter_24\page_5.png
#   Replacements found → saved: output\Chainsawman\Chapter_24\page_6.png
#   Replacements found → saved: output\Chainsawman\Chapter_24\page_7.png
#   Replacements found → saved: output\Chainsawman\Chapter_24\page_8.png
#   Replacements found → saved: output\Chainsawman\Chapter_24\page_9.png
#   No replacements → saved copy: output\Chainsawman\Chapter_24\page_10.png
#   Replacements found → saved: output\Chainsawman\Chapter_24\page_11.png
#   Replacements found → saved: output\Chainsawman\Chapter_24\page_12.png
#   Replacements found → saved: output\Chainsawman\Chapter_24\page_13.png
#   Replacements found → saved: output\Chainsawman\Chapter_24\page_14.png
#   Replacements found → saved: output\Chainsawman\Chapter_24\page_15.png
#   Replacements found → saved: output\Chainsawman\Chapter_24\page_16.png
#   Replacements found → saved: output\Chainsawman\Chapter_24\page_17.png
#   Replacements found → saved: output\Chainsawman\Chapter_24\page_18.png
#
# Processing folder: input\Chainsawman\Chapter_25
#   Replacements found → saved: output\Chainsawman\Chapter_25\page_1.png
#   Replacements found → saved: output\Chainsawman\Chapter_25\page_2.png
#   Replacements found → saved: output\Chainsawman\Chapter_25\page_3.png
#   Replacements found → saved: output\Chainsawman\Chapter_25\page_4.png
#   Replacements found → saved: output\Chainsawman\Chapter_25\page_5.png
#   Replacements found → saved: output\Chainsawman\Chapter_25\page_6.png
#   Replacements found → saved: output\Chainsawman\Chapter_25\page_7.png
#   Replacements found → saved: output\Chainsawman\Chapter_25\page_8.png
#   Replacements found → saved: output\Chainsawman\Chapter_25\page_9.png
#   Replacements found → saved: output\Chainsawman\Chapter_25\page_10.png
#   Replacements found → saved: output\Chainsawman\Chapter_25\page_11.png
#   Replacements found → saved: output\Chainsawman\Chapter_25\page_12.png
#   Replacements found → saved: output\Chainsawman\Chapter_25\page_13.png
#   Replacements found → saved: output\Chainsawman\Chapter_25\page_14.png
#   Replacements found → saved: output\Chainsawman\Chapter_25\page_15.png
#   No replacements → saved copy: output\Chainsawman\Chapter_25\page_16.png
#   Replacements found → saved: output\Chainsawman\Chapter_25\page_17.png
#   Replacements found → saved: output\Chainsawman\Chapter_25\page_18.png
#   Replacements found → saved: output\Chainsawman\Chapter_25\page_19.png

# %%
# (pseudo-command, not run here)
# !easyocr_train -f "wild-words-bold.ttf" -l en -s train_data/
# Out:
# 'easyocr_train' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# --------------------------
# CONFIG
# --------------------------
input_folder = Path(r"input")
output_folder = Path("output")
output_folder.mkdir(exist_ok=True)

allow_chars = "ABCDEFGHIJKLMNOPQRSTUVWXYZ012356789!?.,-…'\""

# Load replacements from JSON file
with open("replacements.json", "r", encoding="utf-8") as f:
    replacements = json.load(f)

font_path = "fonts/CCMeanwhileBoldItalic.ttf"
font_size = 16

# --------------------------
# INITIALIZE OCR
# --------------------------
reader = easyocr.Reader(['en'], gpu=True)

# --------------------------
# HELPER FUNCTIONS
# --------------------------
def natural_sort_key(path):
    return [int(text) if text.isdigit() else text.lower()
            for text in re.split(r'(\d+)', str(path))]

def get_replacement(word, replacements):
    punct = '!?.,-…\'\"'
    core = word.strip(punct)
    key = core.upper()
    if key in replacements:
        core_start = word.find(core)
        pre = word[:core_start]
        post = word[core_start + len(core):]
        return pre + replacements[key] + post
    else:
        return word

def filter_and_replace(results, replacements):
    """Return only the OCR boxes that contain words found in replacements.json."""
    filtered = []
    for bbox, text, conf in results:
        words = text.split()
        replaced_words = []
        found = False
        for word in words:
            replaced_word = get_replacement(word, replacements)
            if replaced_word != word:
                found = True
            replaced_words.append(replaced_word)
        if found:
            new_text = " ".join(replaced_words)
            filtered.append((bbox, new_text, conf))
    return filtered

def draw_text_on_image(img, results, font_path, base_font_size, padding_ratio=0.1):
    """Draws white box + replacement text, scaling font and box to match OCR bbox height."""
    pil_img = img.copy()
    draw = ImageDraw.Draw(pil_img)

    for bbox, text, conf in results:
        # Calculate bounding box height from OCR result
        x_coords = [p[0] for p in bbox]
        y_coords = [p[1] for p in bbox]
        x_center = int(np.mean(x_coords))
        y_center = int(np.mean(y_coords))
        bbox_height = max(y_coords) - min(y_coords)
        bbox_width = max(x_coords) - min(x_coords)

        # Estimate font size proportional to OCR box height
        est_font_size = max(8, int(bbox_height * 0.73))  # Adjust scaling as needed
        font = ImageFont.truetype(font_path, est_font_size)

        # Measure text size using the selected font
        bbox_text = draw.textbbox((0, 0), text, font=font)
        text_width = bbox_text[2] - bbox_text[0]
        text_height = bbox_text[3] - bbox_text[1]

        # Add padding proportional to text size
        padding_x = int(text_width * padding_ratio)
        padding_y = int(text_height * padding_ratio)

        # Define rectangle coordinates
        x0 = x_center - text_width // 2.2 - padding_x
        y0 = y_center - text_height // 2 - padding_y
        x1 = x_center + text_width // 2.2 + padding_x
        y1 = y_center + text_height // 2 + padding_y

        # Draw white rectangle, then replacement text
        draw.rectangle([x0, y0, x1, y1], fill="white")
        draw.text((x_center, y_center), text, fill="black", font=font, anchor="mm")

    return pil_img


# --------------------------
# PROCESS FOLDERS
# --------------------------
folders = [f for f in input_folder.rglob('*') if f.is_dir()] + [input_folder]

for folder in sorted(set(folders)):
    image_files = sorted(
        list(folder.glob("*.webp")) +
        list(folder.glob("*.jpg")) +
        list(folder.glob("*.jpeg")),
        key=natural_sort_key
    )

    if not image_files:
        continue

    print(f"\nProcessing folder: {folder}")

    for img_path in image_files:
        img = Image.open(img_path)
        results = reader.readtext(np.array(img), allowlist=allow_chars, width_ths=0.05)
        # Replace ALL words             (Option 1)
        filtered_results = [(bbox, " ".join([get_replacement(w, replacements) for w in text.split()]), conf) for bbox, text, conf in results]
        # Replace ONLY FILTERED words   (Option 2)
#        filtered_results = filter_and_replace(results, replacements)

        modified_img = draw_text_on_image(img, filtered_results, font_path, font_size)

        relative_path = folder.relative_to(input_folder)
        output_subfolder = output_folder / relative_path
        output_subfolder.mkdir(parents=True, exist_ok=True)

        output_path = output_subfolder / f"{img_path.stem}.png"
        modified_img.save(output_path)
        if filtered_results:
            print(f"  Replacements found → saved: {output_path}")
        else:
            print(f"  No replacements → saved copy: {output_path}")
# Out:
# Processing folder: input\Chainsawman\Chapter_14
#   Replacements found → saved: output\Chainsawman\Chapter_14\page_1.png
#   Replacements found → saved: output\Chainsawman\Chapter_14\page_2.png
#   Replacements found → saved: output\Chainsawman\Chapter_14\page_3.png
#   Replacements found → saved: output\Chainsawman\Chapter_14\page_4.png
#   Replacements found → saved: output\Chainsawman\Chapter_14\page_5.png
#   Replacements found → saved: output\Chainsawman\Chapter_14\page_6.png
#   Replacements found → saved: output\Chainsawman\Chapter_14\page_7.png
#   Replacements found → saved: output\Chainsawman\Chapter_14\page_8.png
#   Replacements found → saved: output\Chainsawman\Chapter_14\page_9.png
#   Replacements found → saved: output\Chainsawman\Chapter_14\page_10.png
#   Replacements found → saved: output\Chainsawman\Chapter_14\page_11.png
#   Replacements found → saved: output\Chainsawman\Chapter_14\page_12.png
#   Replacements found → saved: output\Chainsawman\Chapter_14\page_13.png
#   Replacements found → saved: output\Chainsawman\Chapter_14\page_14.png
#   Replacements found → saved: output\Chainsawman\Chapter_14\page_15.png
#   Replacements found → saved: output\Chainsawman\Chapter_14\page_16.png
#   Replacements found → saved: output\Chainsawman\Chapter_14\page_17.png
#   Replacements found → saved: output\Chainsawman\Chapter_14\page_18.png
#
# Processing folder: input\Chainsawman\Chapter_15
#   Replacements found → saved: output\Chainsawman\Chapter_15\page_1.png
#   Replacements found → saved: output\Chainsawman\Chapter_15\page_2.png
#   Replacements found → saved: output\Chainsawman\Chapter_15\page_3.png
#   Replacements found → saved: output\Chainsawman\Chapter_15\page_4.png
#   Replacements found → saved: output\Chainsawman\Chapter_15\page_5.png
#   Replacements found → saved: output\Chainsawman\Chapter_15\page_6.png
#   Replacements found → saved: output\Chainsawman\Chapter_15\page_7.png
#   Replacements found → saved: output\Chainsawman\Chapter_15\page_8.png
#   Replacements found → saved: output\Chainsawman\Chapter_15\page_9.png
#   Replacements found → saved: output\Chainsawman\Chapter_15\page_10.png
#   Replacements found → saved: output\Chainsawman\Chapter_15\page_11.png
#   Replacements found → saved: output\Chainsawman\Chapter_15\page_12.png
#   Replacements found → saved: output\Chainsawman\Chapter_15\page_13.png
#   Replacements found → saved: output\Chainsawman\Chapter_15\page_14.png
#   Replacements found → saved: output\Chainsawman\Chapter_15\page_15.png
#   Replacements found → saved: output\Chainsawman\Chapter_15\page_16.png
#   Replacements found → saved: output\Chainsawman\Chapter_15\page_17.png
#   Replacements found → saved: output\Chainsawman\Chapter_15\page_18.png
#   Replacements found → saved: output\Chainsawman\Chapter_15\page_19.png
#   Replacements found → saved: output\Chainsawman\Chapter_15\page_20.png
#   Replacements found → saved: output\Chainsawman\Chapter_15\page_21.png
